# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Requirement already satisfied: librosa==0.10.0 in c:\users\abdul\anaconda3\lib\site-packages (from -r ./requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: pandas in c:\users\abdul\anaconda3\lib\site-packages (from -r ./requirements.txt (line 2)) (1.4.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\abdul\anaconda3\lib\site-packages (from librosa==0.10.0->-r ./requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\abdul\anaconda3\lib\site-packages (from librosa==0.10.0->-r ./requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\abdul\anaconda3\lib\site-packages (from librosa==0.10.0->-r ./requirements.txt (line 1)) (1.7.0)
# Requirement already satisfied: numba>=0.51.0 in c:\users\abdul\anaconda3\lib\site-packages (from librosa==0.10.0->-r ./requirements.txt (line 1)) (0.55.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\abdul\anaconda3\lib\site-packages (from librosa==0.10.0->-r ./requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: msgpack>=1.0 in c:\users\abdul\anaconda3\lib\site-packages (from librosa==0.10.0->-r ./requirements.txt (line 1)) (1.0.2)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\abdul\anaconda3\lib\site-packages (from librosa==0.10.0->-r ./requirements.txt (line 1)) (0.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\abdul\anaconda3\lib\site-packages (from librosa==0.10.0->-r ./requirements.txt (line 1)) (1.0.2)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\abdul\anaconda3\lib\site-packages (from librosa==0.10.0->-r ./requirements.txt (line 1)) (0.3.5)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\abdul\anaconda3\lib\site-packages (from librosa==0.10.0->-r ./requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\abdul\anaconda3\lib\site-packages (from librosa==0.10.0->-r ./requirements.txt (line 1)) (4.1.1)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\abdul\anaconda3\lib\site-packages (from librosa==0.10.0->-r ./requirements.txt (line 1)) (1.7.3)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\abdul\anaconda3\lib\site-packages (from librosa==0.10.0->-r ./requirements.txt (line 1)) (1.21.6)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abdul\anaconda3\lib\site-packages (from pandas->-r ./requirements.txt (line 2)) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\abdul\anaconda3\lib\site-packages (from pandas->-r ./requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: setuptools in c:\users\abdul\anaconda3\lib\site-packages (from numba>=0.51.0->librosa==0.10.0->-r ./requirements.txt (line 1)) (61.2.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\abdul\anaconda3\lib\site-packages (from numba>=0.51.0->librosa==0.10.0->-r ./requirements.txt (line 1)) (0.38.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\abdul\anaconda3\lib\site-packages (from pooch>=1.0->librosa==0.10.0->-r ./requirements.txt (line 1)) (21.3)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\abdul\anaconda3\lib\site-packages (from pooch>=1.0->librosa==0.10.0->-r ./requirements.txt (line 1)) (3.5.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\abdul\anaconda3\lib\site-packages (from pooch>=1.0->librosa==0.10.0->-r ./requirements.txt (line 1)) (2.27.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\abdul\anaconda3\lib\site-packages (from packaging>=20.0->pooch>=1.0->librosa==0.10.0->-r ./requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\abdul\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->-r ./requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abdul\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.10.0->-r ./requirements.txt (line 1)) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\abdul\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.10.0->-r ./requirements.txt (line 1)) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abdul\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.10.0->-r ./requirements.txt (line 1)) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\abdul\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.10.0->-r ./requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\abdul\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa==0.10.0->-r ./requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\abdul\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa==0.10.0->-r ./requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\abdul\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa==0.10.0->-r ./requirements.txt (line 1)) (2.21)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8e3e1d63-2a55-4dcb-8826-d15658c6a54b' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
